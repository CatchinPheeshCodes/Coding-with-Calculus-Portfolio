# %% [markdown]
# ## Travis Williams - trwi4612

# %% [markdown]
# #### 1. Pg. 115 #2(a) : $f^\prime(1) \space where \space f(x) = x^4 − 8x.$

# %%
##defining function that will allow us to zoom in on f(1)##
import numpy as np
import matplotlib.pyplot as plt

def func(x):
    #calculating yprime for each x.
    return x ** 4 - 8 * x

def plot(xinit, xend, steps):
    #generate x values.
    x_range = np.linspace(xinit, xend, steps)
    
    #generate y values.
    y = func(x_range)
    #calculate and print slope.
    print('Slope: ', (y[-1]-y[0]) / (x_range[-1] - x_range[0]))
    
    #plot the coordinates.
    plt.plot(x_range, y)
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.grid(True)
    plt.show()

# %%
plot(0, 2, 100)
# Out:
# Slope:  0.0

# %%
plot(0.75, 1.25,100)
# Out:
# Slope:  -3.75

# %%
plot(0.96, 1.04, 100)
# Out:
# Slope:  -3.9936000000000047

# %%
plot(0.97, 1.03, 100)
# Out:
# Slope:  -3.9964

# %% [markdown]
# #### Explanation:
#
# The first two graphs above show broader prespectives for the graph $f(x)=4^x-8x$.  The first graph shows the curve for this function between $f(0)$ and $f(2)$.  To illustrate the process of zooming in, the second graph shows the curve for this function between $f(0.75)$ and $f(1.25)$.  The slope, $\Delta x/ \Delta y$, is calculated for each graph.
#
# As we continue to zoom in, graphs 3 and 4 show the plots for $f(0.96)$ to $f(1.04)$ and $f(0.97)$ to $f(1.03)$, respectively.  These two plots illustrate the sequence of windows where the first two decimal places of the slope calculation stabilize. Here, the slope stabilizies at 3.99...

# %% [markdown]
# #### 2. 10 pp 118/119. -- Credit: Christopher Taylor. Viewed Piazza post prior to starting on this question.
# a. False.  $g^\prime(t)$ being positive for all t means that the slope is increasing for all t.  $g(214)$ can still be negative.  Let's assume that $g^\prime(t) = t - 215$.  $g^\prime(213) = -2$ $g^\prime(214) = -1$. $g^\prime$ is increasing, but $g(214)$ is negative. <br>
# b. True.  $217 > 4$ and we know that $g^\prime(t)$, the rate of change, is increasing for all t.  Since $t = 217$ is greater than $t = 4$ and the rate of change is always increasing, we can conclude that the rate of change for the larger value of $t$ will always be be greater than that of the smaller value. <br>
# c. True.  In this scenario, speed represents the rate of change over the distance travelled in 20 minutes and remains constant for the duration of the journey.  If Bill and Samantha maintain the exact same speed, Samantha will still be 1 mile ahead of Bill after 20 minutes. <br>
# d. True. If they start at the same origin at 10am and arrive at their destination at the exact same time, their speeds must have been exactly the same at some point during the journey.  Two scenarios could apply here: <br>
# 1. Bill and Samantha travel at the exact same speed for the entire duration of the journey.
# 2. Bill starts out driving faster than Samantha at the beginning of the journey and Samantha ends the journey driving faster than Bill, or vice versa.  At some point, one person must pass the other person in order for them to arrive at the same time.  At that moment, Bill and Samantha would be driving at the same speed.

# %% [markdown]
# #### 3. #2 (a,b,c,d) p. 131

# %%
#2a. plotting f(x) = 1 / x
##defining function that will allow us to zoom in on f(2)##
import numpy as np
import matplotlib.pyplot as plt

def func2(x):
    #calculating yprime for each x.
    return 1 / x

def plot2(xinit, xend, steps):
    #generate x values.
    x_range = np.linspace(xinit, xend, steps)
    
    #generate y values.
    y = func2(x_range)
    #calculate and print slope.
    print('Slope: ', (y[-1]-y[0]) / (x_range[-1] - x_range[0]))
    
    #plot the coordinates.
    plt.plot(x_range, y)
    
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.grid(True)
    plt.show()

# %%
plot2(1, 3, 100)
# Out:
# Slope:  -0.33333333333333337

# %%
plot2(1.999999, 2.000001, 100)
# Out:
# Slope:  -0.24999999997224442

# %%
#2a. defining function to calculate derivative with formula f(a + h) - f(a - h) / 2h where x = a. f(x) = 1 / x
def deriv(x):
    h = [0.01, 0.001, 0.0001, 0.00001, 0.000001]
    for i in range(len(h)):
        d = ((1 / (x + h[i])) - (1 / (x - h[i]))) / (2 * h[i])
        print(d)
    return
deriv(2)
# Out:
# -0.25000625015624833
# -0.25000006249997764
# -0.25000000062558314
# -0.2500000000099645
# -0.24999999997943334

# %% [markdown]
# #### 2. Explanation
#
# The first graph above plots the '30,000 foot' view of the function $f(x)=1/x$.  The second graph zooms in and shows the plot for this function where it appears to be straight, and the slope stabilizes to 2 decimal points. The python function deriv() calculates the derivative based on the quotients that are listed in the textbook.  Here, we can compare the accuracy of the mathematical computation with the more manual process of zooming in on the function until the rate of change stabilizes.  Interestingly enough, we can find a very close match between slopes calculated with microscope method and the slopes calculated with the function deriv() by closely approximating a range that matches any of ther iterations of h.
#
# Similar results can be found below for parts b, c, & d.

# %%
#2b. plotting f(x) = sin(7x) at x = 3.
##defining function that will allow us to zoom in on f(3)##
import numpy as np
import matplotlib.pyplot as plt

def func3(x):
    #calculating yprime for each x.
    return np.sin((7 * x))

def plot3(xinit, xend, steps):
    #generate x values.
    x_range = np.linspace(xinit, xend, steps)
    
    #generate y values.
    y = func3(x_range)
    #calculate and print slope.
    print('Slope: ', (y[-1]-y[0]) / (x_range[-1] - x_range[0]))
    
    #plot the coordinates.
    plt.plot(x_range, y)
    
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.grid(True)
    plt.show()

# %%
plot3(2, 4, 100)
# Out:
# Slope:  -0.35985078369350065

# %%
plot3(2.999999, 3.000001, 100)
# Out:
# Slope:  -3.8341048210402775

# %%
#2b. defining function to calculate derivative with formula f(a + h) - f(a - h) / 2h where x = a. f(x) = sin(7x)
def deriv2(x):
    h = [0.01, 0.001, 0.0001, 0.00001, 0.000001]
    for i in range(len(h)):
        d = (np.sin((7 * x) + h[i]) - np.sin((7 * x) - h[i])) / (2 * h[i])
        print(d)
    return
deriv2(3)
# Out:
# -0.5477201314489921
# -0.5477291689367503
# -0.5477292593097927
# -0.547729260197416
# -0.5477292607802831

# %%
#2c. 
##defining function that will allow us to zoom in on f(200)##
import numpy as np
import matplotlib.pyplot as plt

def func4(x):
    #calculating yprime for each x.
    return x ** 3

def plot4(xinit, xend, steps):
    #generate x values.
    x_range = np.linspace(xinit, xend, steps)
    
    #generate y values.
    y = func4(x_range)
    #calculate and print slope.
    print('Slope: ', (y[-1]-y[0]) / (x_range[-1] - x_range[0]))
    
    #plot the coordinates.
    plt.plot(x_range, y)
    
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.grid(True)
    plt.show()

# %%
plot4(150, 250, 100)
# Out:
# Slope:  122500.0

# %%
plot4(199.999999, 200.000001, 100)
# Out:
# Slope:  119999.9999490683

# %%
#2c. defining function to calculate derivative with formula f(a + h) - f(a - h) / 2h where x = a. f(x) = x^3
def deriv3(x):
    h = [0.01, 0.001, 0.0001, 0.00001, 0.000001]
    for i in range(len(h)):
        d = (((x + h[i]) ** 3) - ((x - h[i]) ** 3)) / (2 * h[i])
        print(d)
    return
deriv3(200)
# Out:
# 120000.00009988435
# 120000.00000186265
# 120000.00000465661
# 120000.00006519257
# 119999.99964609742

# %%
#2d. 
##defining function that will allow us to zoom in on f(5)##
import numpy as np
import matplotlib.pyplot as plt

def func5(x):
    #calculating yprime for each x.
    return 2 ** x

def plot5(xinit, xend, steps):
    #generate x values.
    x_range = np.linspace(xinit, xend, steps)
    
    #generate y values.
    y = func5(x_range)
    #calculate and print slope.
    print('Slope: ', (y[-1]-y[0]) / (x_range[-1] - x_range[0]))
    
    #plot the coordinates.
    plt.plot(x_range, y)
    
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.grid(True)
    plt.show()

# %%
plot5(4, 6, 100)
# Out:
# Slope:  24.0

# %%
plot5(4.99, 5.01, 100)
# Out:
# Slope:  22.18088739149267

# %%
#2d. defining function to calculate derivative with formula f(a + h) - f(a - h) / 2h where x = a. f(x) = 2^x
def deriv4(x):
    h = [0.01, 0.001, 0.0001, 0.00001, 0.000001]
    for i in range(len(h)):
        d = (2 ** (x + h[i]) - 2 ** (x - h[i])) / (2 * h[i])
        print(d)
    return
deriv4(5)
# Out:
# 22.1808873914922
# 22.180711554058874
# 22.180709795645015
# 22.180709777153137
# 22.180709779107133

# %%
4. #3a. Calculating values of q1 & q2 for k = 0...8. Plotting graph for 3(d).
import matplotlib.pyplot as plt
a = 1
h_list = []
q1_list = []
q2_list = []
for k in range(0, 9):
    h = 1 / 2 ** k
    q1 = ((a + h) ** 3 - (a - h) ** 3) / (2 * h)
    q2 = ((a + h) ** 3 - a ** 3) / h
    
    print(h, q1, q2)
    h_list.append(h)
    q1_list.append(q1)
    q2_list.append(q2)

plt.plot(h_list, q1_list, marker = "o")
plt.plot(h_list, q2_list, marker = "o")
plt.grid(True)
# Out:
# 1.0 4.0 7.0
# 0.5 3.25 4.75
# 0.25 3.0625 3.8125
# 0.125 3.015625 3.390625
# 0.0625 3.00390625 3.19140625
# 0.03125 3.0009765625 3.0947265625
# 0.015625 3.000244140625 3.047119140625
# 0.0078125 3.00006103515625 3.02349853515625
# 0.00390625 3.0000152587890625 3.0117340087890625

# %% [markdown]
# 3(b). 5 digits stabilize for $Q1$. $3.0000$. 2 digits stabilize for $Q2$ $3.0$. <br>
# 3(c). Since more digits stabilize for $Q1$, it is the better stabilizer.  $Q1$ stabilizes to 2 digits when $h = 0.25$, whereas $Q2$ doesn't stabilize to two digits until $h = 0.03125$.

# %% [markdown]
# #### 5. #4, use code p131

# %%
import matplotlib.pyplot as plt
import numpy as np
a = 9
h_list = []
q1_list = []
q2_list = []
for k in range(0, 9):
    h = 1 / 2 ** k
    q1 = (np.sqrt((a + h)) - np.sqrt((a - h))) / (2 * h)
    q2 = (np.sqrt((a + h)) - np.sqrt(a)) / h
    
    print(h, q1, q2)
    h_list.append(h)
    q1_list.append(q1)
    q2_list.append(q2)

plt.plot(h_list, q1_list, marker = "o")
plt.plot(h_list, q2_list, marker = "o")
plt.grid(True)
# Out:
# 1.0 0.16692526771109462 0.16227766016837952
# 0.5 0.16673105406183764 0.16441400296897601
# 0.25 0.1666827471986032 0.16552506059643868
# 0.125 0.16667068578158784 0.16609194718914466
# 0.0625 0.16666767138179495 0.1663783151691831
# 0.03125 0.16666691784147503 0.16652224137045835
# 0.015625 0.1666667294601183 0.16659439142901533
# 0.0078125 0.16666668236501891 0.16663051337502566
# 0.00390625 0.16666667059126894 0.16664858609942712

# %% [markdown]
# 4b. 8 digits stabilize for $Q1$.  5 digits stabilize for $Q2$.
# 4c. Again, $Q1$ is the better stabilizer.  $Q1$ stabilizes to 5 digits at $h = 0.25$, whereas $Q2$ doesn't stabilize to 5 digits until $h = 0.0078125$.

# %% [markdown]
# #### 6. #6, p.132

# %%
def deriv_6(x): #f(a + h) - f(a - h) / 2h for y = 2^x, y = 3^x, y = 10^x, y = (1/2)^x.
    h = 0.01
    print("y = 2^x: ", ((2 ** (x + h)) - (2 ** (x - h))) / (2 * h))
    print("y = 3^x: ", ((3 ** (x + h)) - (3 ** (x - h))) / (2 * h))
    print("y = 10^x: ", ((10 ** (x + h)) - (10 ** (x - h))) / (2 * h))
    print("y = (1/2)^x: ", (((1/2) ** (x + h)) - ((1/2) ** (x - h))) / (2 * h))
    return
deriv_6(0)
# Out:
# y = 2^x:  0.6931527309841479
# y = 3^x:  1.098634388284142
# y = 10^x:  2.3027885662471714
# y = (1/2)^x:  -0.6931527309841479

# %% [markdown]
# We know that a smaller h can result in better stabilization, but I thought that this would be a good place to show how accurate this equation can be with a larger h. Through many of the exercises, we were asked to find where the derivative stabilizes to just two decimal points.  In this example, h = 0.01 stabilizes to 3 decimal points for all of the functions.  While we can be more precise, I thought that it would be interesting to choose a larger h for this exercise.

# %% [markdown]
# #### 7. #15 p134 - credit: Christopher Taylor.  I viewed his answer on piazza before completing this question.
#
# The linear approximation formula allows us to substitute the values provided for $f(a)$ and $f^\prime (a)$. in order to solve the problem.
#
# $f(a) = b$ <br>
# $f^\prime(a) = -3$ <br>
# $f(a+k)\approx f(a)+f^\prime (a) \times k$ **linear approximation formula** <br>
# $f(a+k)\approx b +(-3) \times k$ **Substitute** <br>
# $f(a+k)\approx b - 3k$ **Simplify** <br>
#
# This is an informal proof that shows that, out of the choices given, $b-3k$ will best approximate $f(a+k)$.

# %%
import matplotlib.pyplot as plt

b = 2
x_plot = []
y_plot = []
for k in range(10):
    y = b - 3 * k
    x_plot.append(k)
    y_plot.append(y)

plt.plot(x_plot, y_plot)

# %% [markdown]
# #### 8. #16 p134

# %%
import matplotlib.pyplot as plt
#plotting f(x) = x^3 with each calculation.
def num8(l, u):
    a = 1
    #h = 0.01
    h_list = []
    q1_list = []
    q2_list = []
    q3_list = []
    q4_list = []
    for k in range(0, 9):
        h = 1 / 2 ** k
        q1 = ((a + h) ** 3 - (a - h) ** 3) / h
        q2 = ((a + h) ** 3 - (h ** 3)) / h
        q3 = ((a + h) ** 3 - (a - h) ** 3) / (2 * h)
        q4 = ((a + h) ** 3 - (a - h) ** 3) / (3 * h)

        h_list.append(h)
        q1_list.append(q1)
        q2_list.append(q2)
        q3_list.append(q3)
        q4_list.append(q4)

    #print(q1, q2, q3, q4)
    
    plt.plot(h_list, q1_list, marker = "o", label = "f(a + h) - f(a - h) / h")
    plt.plot(h_list, q2_list, marker = "o", label = "f(a + h) - f(h) / h")
    plt.plot(h_list, q3_list, marker = "o", label = "f(a + h) - f(a - h) / 2h")
    plt.plot(h_list, q4_list, marker = "o", label = "f(a + h) - f(a - h) / 3h")
    plt.grid(True)
    plt.xlabel('h')
    plt.ylabel('deriv')
    plt.ylim(l, u)
    plt.legend()

    return

# %%
num8(0, 300)

# %%
num8(0, 10)

# %% [markdown]
# For this problem, I used $f(x) = x^2$ as the function to calculate the derivative for.  This function stabilizes to two decimal points with h = 0.01, so I used that as my h value.  Otherwise, q2 in the code above grows too large.  The window for the first graph is large enough to show the plots for all 4 variations.  The window for the second graph is zoomed into the range that shows q1, q3, and q4 as they are much closer together and more interesting to compare.
#
# When h is small, you could say that $\frac{f(a+h) - f(a-h)}{3h}$ is reasonable, compared to the central difference formula.  It is closest out of the other 3 equations that we are considering here.  $\frac{f(a+h) - f(h)}{h}$ is entirely unreasonable, and $\frac{f(a+h) - f(a-h)}{h}$ doesn't seem close enough to the results of the central difference formula to reasonable estimate $f^\prime (a)$.
